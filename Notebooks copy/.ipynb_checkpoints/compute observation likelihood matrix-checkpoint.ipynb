# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
# MLE of the emission probability is count(tag,word) / count(tag)

# %%
# read in training
train = pd.read_table("/Users/amyburkhardt/Dropbox/NLP Readings/hw 1/POS-training.txt",'\t', 
                      header=None, 
                      skip_blank_lines=False, 
                      keep_default_na = False,
                      names = ['word_Num', 'word', 'tag'])

# %%
tags = ['CC', 'CD',
        'DT',
        'EX',
        'FW',
        'IN', 
        'JJ', 'JJR', 'JJS',
        'LS', 
        'MD',
        'NN', 'NNS', 'NNP', 'NNPS',
        'PDT', 'POS', 'PRP', 'PRP$',
        'RB', 'RBR', 'RBS', 'RP',
        'SYM', 
        'TO', 
        'UH', 
        'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ',
        'WDT', 'WP', 'WP$', 'WRB', 
        '$', '#', '"', '(', ')', ',', '.', ':'
       ]

# %%
def ngram_dict(data, ngrams, specify = "tag_word"):
    """
    Creates dict of ngrams (key) and count (value). 
    
    Arguments: 
        data: DataFrame with 'tag' and 'word' colum
        ngrams: denote if "bigram" or "unigram"
        specify: denote type of bi-grams: word_word or tag_word
    Returns:
        A dict where key is either a unigram or a bigram tuple, and value is the count of the ngrams
    """
    if specify == "tag_tag": 
        if ngrams == "bigram": 
            col_1 = data['tag']
            col_2 = col_1[1:col_1.shape[0]]
            ngram_count = list(zip(col_1, col_2))
            ngram_count = dict(Counter(ngram_count))

        if ngrams == 'unigram': 
                ngram_count = dict(Counter(data.tag))
    
    if specify == "tag_word":
        if ngrams == 'bigram': 
            col_1 = data['tag']
            col_2 = data['word'][1:col_1.shape[0]]
            ngram_count = list(zip(col_1, col_2))
            ngram_count = dict(Counter(ngram_count))
            
        
        if ngrams == 'unigram': 
            ngram_count = dict(Counter(data.word))
            
    return ngram_count

# %%
bigrams = ngram_dict(train, "bigram", "tag_word")
unigrams = ngram_dict(train,"unigram", "tag_word")

# %%
# replace words that appear less than three times with UNK in training data

# %%
# get words that we will call unknowns, and replace these instances in the dataframe
unknowns = { key:value for key, value in unigrams.items() if value < 3 }
dictlist = []
for key,value in unknowns.items():
    dictlist.append(key)

# %%
dictlist
# Out:
# ['served',
#  'southwest',
#  'depends',
#  'vegan',
#  'personal',
#  'poland',
#  'sundae',
#  'steaks',
#  'credit',
#  'nina',
#  'health',
#  'rupees',
#  'concerning',
#  'violeta',
#  'christmas',
#  'menus',
#  'cards',
#  'brennan',
#  'dog',
#  'who',
#  'omnivore',
#  'finished',
#  'senior',
#  'cookie',
#  'session',
#  'traditional',
#  'requirements',
#  'weekdays',
#  "zachary's",
#  'rolls',
#  'sudanese',
#  'totally',
#  'parking',
#  'irrelevant',
#  'base',
#  'thinks',
#  'waffles',
#  'special',
#  'looks',
#  'ah',
#  'hot',
#  "lococo's",
#  'checks',
#  'enchiladas',
#  'taquerias',
#  'lots',
#  'anyplace',
#  'beni',
#  'done',
#  "juan's",
#  'paz',
#  'suggestion',
#  'cheese',
#  'pastries',
#  'specifically',
#  'doing',
#  'gingerbread',
#  'freeway',
#  'shops',
#  'parlors',
#  'hang',
#  'healthy',
#  'match',
#  'copy',
#  "doesn't",
#  'regular',
#  'talking',
#  'wherever',
#  'public',
#  'rockridge',
#  'chance',
#  'allows',
#  'appreciate',
#  'southwestern',
#  'cal',
#  'displaying',
#  'lo',
#  'issue',
#  'bell',
#  'pesos',
#  "kip's",
#  'decided',
#  'bongo',
#  'caviar',
#  'delhi',
#  'junction',
#  'non-vegetarian',
#  'course',
#  'forget',
#  'rest',
#  'source',
#  'head',
#  'saw',
#  'bakeries',
#  'grace',
#  'road',
#  'perhaps',
#  'arabic',
#  'chocolate',
#  'talk',
#  'spot',
#  'park',
#  'print',
#  'directions',
#  'data',
#  'fruit',
#  'rib',
#  'offers',
#  'eye',
#  'planning',
#  'referred',
#  'shop',
#  'buy',
#  'saturdays',
#  "plearn's",
#  'sentence',
#  'enjoy',
#  'fu',
#  'thanksgiving',
#  "govinda's",
#  'peru',
#  'realized',
#  'answer',
#  'hama',
#  'smoking',
#  'top',
#  'eighty',
#  'higher',
#  'andean',
#  'basque',
#  'probably',
#  'read',
#  'choose',
#  'reach',
#  'iranian',
#  "basil's",
#  'expand',
#  'owner',
#  'india',
#  'coke',
#  'problem',
#  'shows',
#  'malts',
#  "panini's",
#  'houses',
#  'eighteen',
#  'gertie',
#  'job',
#  'whenever',
#  'cookies',
#  'service',
#  'interesting',
#  'liquor',
#  'cool',
#  'insist',
#  'unlimited',
#  'breakfasts',
#  'pardon',
#  'whatever',
#  'actual',
#  'creme-de-la-creme',
#  'billion',
#  'feel',
#  'asked',
#  'stop',
#  'move']

# %%
for key, value in unknowns.items():
    if train['word']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-6f79d80ac0a3> in <module>()
#       1 for key, value in unknowns.items():
# ----> 2     if train['word']:
#       3         print(key)
#
# ~/Documents/NLP/venv/lib/python3.5/site-packages/pandas/core/generic.py in __nonzero__(self)
#     953         raise ValueError("The truth value of a {0} is ambiguous. "
#     954                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 955                          .format(self.__class__.__name__))
#     956
#     957     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
train['word']
# Out:
# 0                  i
# 1                 'd
# 2               like
# 3                 to
# 4                 go
# 5                 to
# 6                  a
# 7              fancy
# 8         restaurant
# 9                  .
# 10
# 11                 i
# 12                'd
# 13              like
# 14            french
# 15              food
# 16                 .
# 17
# 18              next
# 19          thursday
# 20                 .
# 21
# 22              next
# 23          thursday
# 24                 .
# 25
# 26            dinner
# 27                 .
# 28
# 29                 i
#              ...
# 154015            be
# 154016        eleven
# 154017          a__m
# 154018            to
# 154019           one
# 154020          p__m
# 154021             .
# 154022
# 154023             i
# 154024          like
# 154025            to
# 154026           eat
# 154027            uh
# 154028             i
# 154029          like
# 154030            to
# 154031           eat
# 154032            at
# 154033         lunch
# 154034          time
# 154035            so
# 154036          that
# 154037         would
# 154038            be
# 154039        eleven
# 154040          a__m
# 154041            to
# 154042           one
# 154043          p__m
# 154044             .
# Name: word, Length: 154045, dtype: object

# %%
unknowns
# Out:
# {'actual': 1,
#  'ah': 2,
#  'allows': 2,
#  'andean': 2,
#  'answer': 1,
#  'anyplace': 2,
#  'appreciate': 1,
#  'arabic': 1,
#  'asked': 2,
#  'bakeries': 2,
#  'base': 2,
#  "basil's": 2,
#  'basque': 1,
#  'bell': 2,
#  'beni': 1,
#  'billion': 2,
#  'bongo': 1,
#  'breakfasts': 1,
#  'brennan': 2,
#  'buy': 1,
#  'cal': 2,
#  'cards': 2,
#  'caviar': 2,
#  'chance': 2,
#  'checks': 1,
#  'cheese': 2,
#  'chocolate': 2,
#  'choose': 2,
#  'christmas': 1,
#  'coke': 2,
#  'concerning': 2,
#  'cookie': 1,
#  'cookies': 1,
#  'cool': 1,
#  'copy': 1,
#  'course': 2,
#  'credit': 2,
#  'creme-de-la-creme': 1,
#  'data': 2,
#  'decided': 2,
#  'delhi': 2,
#  'depends': 1,
#  'directions': 1,
#  'displaying': 2,
#  "doesn't": 1,
#  'dog': 2,
#  'doing': 2,
#  'done': 2,
#  'eighteen': 1,
#  'eighty': 1,
#  'enchiladas': 1,
#  'enjoy': 1,
#  'expand': 1,
#  'eye': 2,
#  'feel': 1,
#  'finished': 1,
#  'forget': 1,
#  'freeway': 2,
#  'fruit': 1,
#  'fu': 2,
#  'gertie': 2,
#  'gingerbread': 2,
#  "govinda's": 2,
#  'grace': 2,
#  'hama': 1,
#  'hang': 1,
#  'head': 1,
#  'health': 1,
#  'healthy': 2,
#  'higher': 1,
#  'hot': 2,
#  'houses': 2,
#  'india': 1,
#  'insist': 2,
#  'interesting': 1,
#  'iranian': 2,
#  'irrelevant': 1,
#  'issue': 1,
#  'job': 2,
#  "juan's": 2,
#  'junction': 2,
#  "kip's": 1,
#  'liquor': 1,
#  'lo': 2,
#  "lococo's": 1,
#  'looks': 1,
#  'lots': 2,
#  'malts': 2,
#  'match': 1,
#  'menus': 1,
#  'move': 1,
#  'nina': 1,
#  'non-vegetarian': 2,
#  'offers': 2,
#  'omnivore': 1,
#  'owner': 2,
#  "panini's": 1,
#  'pardon': 2,
#  'park': 1,
#  'parking': 1,
#  'parlors': 2,
#  'pastries': 2,
#  'paz': 2,
#  'perhaps': 1,
#  'personal': 1,
#  'peru': 2,
#  'pesos': 1,
#  'planning': 2,
#  "plearn's": 1,
#  'poland': 1,
#  'print': 2,
#  'probably': 1,
#  'problem': 1,
#  'public': 1,
#  'reach': 2,
#  'read': 1,
#  'realized': 2,
#  'referred': 1,
#  'regular': 1,
#  'requirements': 1,
#  'rest': 1,
#  'rib': 2,
#  'road': 2,
#  'rockridge': 2,
#  'rolls': 1,
#  'rupees': 2,
#  'saturdays': 1,
#  'saw': 2,
#  'senior': 2,
#  'sentence': 1,
#  'served': 2,
#  'service': 2,
#  'session': 2,
#  'shop': 1,
#  'shops': 1,
#  'shows': 1,
#  'smoking': 2,
#  'source': 1,
#  'southwest': 2,
#  'southwestern': 2,
#  'special': 1,
#  'specifically': 1,
#  'spot': 1,
#  'steaks': 2,
#  'stop': 2,
#  'sudanese': 1,
#  'suggestion': 1,
#  'sundae': 2,
#  'talk': 1,
#  'talking': 1,
#  'taquerias': 1,
#  'thanksgiving': 1,
#  'thinks': 1,
#  'top': 2,
#  'totally': 1,
#  'traditional': 2,
#  'unlimited': 1,
#  'vegan': 2,
#  'violeta': 2,
#  'waffles': 1,
#  'weekdays': 2,
#  'whatever': 1,
#  'whenever': 2,
#  'wherever': 1,
#  'who': 2,
#  "zachary's": 1}

# %%
bigram_counts = ngram_dict(train, "bigram", "tag_word")
unigram_counts = ngram_dict(train, "unigram")

# %%
unigram_counts
# Out:
# {'': 14900,
#  '.': 14901,
#  ':': 5,
#  'CC': 2008,
#  'CD': 3951,
#  'DT': 8063,
#  'EX': 432,
#  'FW': 355,
#  'HYPH': 539,
#  'IN': 12696,
#  'JJ': 7363,
#  'JJR': 1508,
#  'JJS': 321,
#  'LS': 9,
#  'MD': 4717,
#  'NN': 21147,
#  'NNP': 686,
#  'NNS': 5570,
#  'PDT': 116,
#  'POS': 578,
#  'PRP': 12334,
#  'PRP$': 272,
#  'RB': 5629,
#  'RBR': 409,
#  'RBS': 22,
#  'RP': 941,
#  'TO': 4790,
#  'UH': 3964,
#  'VB': 13727,
#  'VBD': 527,
#  'VBG': 946,
#  'VBN': 391,
#  'VBP': 5522,
#  'VBZ': 2305,
#  'WDT': 581,
#  'WP': 748,
#  'WRB': 1072}

# %%
# probabilities are computed as the following: 
# out of the times we see the first tag in a labeled corpus (denominator)
# how often is the first tag folowed by the second (numerator)

# %%
def compute_transition_matrix (tags, bigram_counts, unigram_counts):
    """
    Compute probabilities for the transition matrix (45 x 44)
    
    Arguments: 
        tags: POS tags (that may or may not appear in training data)
        bigram_counts: count of bigrams of POS tags in training data (used for numerator)
        unigram_counts: count of unigram POS tag in training data (used for denominator)
        
    Returns: 45 x 44 matrix of transition probabilities for all possible POS tags
    
    """

    transition = [] # list of transition probabilities 
    
    # first compute the starting probabilities 

    for x in tags: 
            pair = ('',x) # here the period denotes the start of a sentence. Not very confident about this
            print(pair)
            denominator = unigram_counts['']
            try: 
                 numerator = bigram_counts[pair] + 1 
            except:
                 numerator = 1
            transition.append(numerator / denominator)


    # then compute everything else 
    
    for x in tags:
        for y in tags:
            pair = (x,y)
            try:
                denominator = unigram_counts[x] + 1 
            except: 
                denominator = 1
            try: 
                numerator = bigram_counts[pair] + 1 
            except:
                numerator = 1 # this produces probabilities of 1, when they should be much loser to zero; not right. 
            transition.append(numerator / denominator)
   
    
    transition = np.array(transition)
    tran_matrix = transition.reshape(45,44)
    
    return tran_matrix

# %%
tran = compute_transition_matrix (tags, bigram_counts, unigram_counts)
# Out:
# ('', 'CC')
# ('', 'CD')
# ('', 'DT')
# ('', 'EX')
# ('', 'FW')
# ('', 'IN')
# ('', 'JJ')
# ('', 'JJR')
# ('', 'JJS')
# ('', 'LS')
# ('', 'MD')
# ('', 'NN')
# ('', 'NNS')
# ('', 'NNP')
# ('', 'NNPS')
# ('', 'PDT')
# ('', 'POS')
# ('', 'PRP')
# ('', 'PRP$')
# ('', 'RB')
# ('', 'RBR')
# ('', 'RBS')
# ('', 'RP')
# ('', 'SYM')
# ('', 'TO')
# ('', 'UH')
# ('', 'VB')
# ('', 'VBD')
# ('', 'VBG')
# ('', 'VBN')
# ('', 'VBP')
# ('', 'VBZ')
# ('', 'WDT')
# ('', 'WP')
# ('', 'WP$')
# ('', 'WRB')
# ('', '$')
# ('', '#')
# ('', '"')
# ('', '(')
# ('', ')')
# ('', ',')
# ('', '.')
# ('', ':')

# %%
tran
# Out:
# array([[  1.67785235e-03,   1.41610738e-02,   4.86577181e-02, ...,
#           6.71140940e-05,   1.34228188e-04,   6.71140940e-05],
#        [  4.97760080e-04,   1.06022897e-01,   9.25833748e-02, ...,
#           4.97760080e-04,   4.97760080e-04,   4.97760080e-04],
#        [  4.88360324e-02,   7.21153846e-02,   2.53036437e-04, ...,
#           2.53036437e-04,   1.08805668e-02,   2.53036437e-04],
#        ...,
#        [  1.00000000e+00,   1.00000000e+00,   1.00000000e+00, ...,
#           1.00000000e+00,   1.00000000e+00,   1.00000000e+00],
#        [  6.71050866e-05,   6.71050866e-05,   6.71050866e-05, ...,
#           6.71050866e-05,   6.71050866e-05,   6.71050866e-05],
#        [  1.66666667e-01,   1.66666667e-01,   1.66666667e-01, ...,
#           1.66666667e-01,   1.66666667e-01,   1.66666667e-01]])
