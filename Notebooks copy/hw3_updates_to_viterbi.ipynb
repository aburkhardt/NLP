# %%
# %run ~/Documents/NLP/Code/burkhardt-amy-assgn4.py
# Out:
# Missing arguments.
# Usage: burkhardt-amy-assgn2.py trainingfile.txt testfile.txt > burkhardt-amy-assgn2-test-output.txt

# %%
train = get_data("/Users/amyburkhardt/Dropbox/NLP Readings/hw3/rand_training.txt")

# %%
test = get_data("/Users/amyburkhardt/Dropbox/NLP Readings/hw3/rand_test.txt")

# %%
vocabulary = get_vocabulary(train, min_freq=2)

# %%
transition = get_transition(train, k=.01)

# %%
observation = get_observation(train, vocabulary, k=.01)

# %%
observation
# Out:
# array([[-17.06716457, -18.06000478, -16.07075783, ..., -16.48459658,
#         -14.75099   , -13.21588168],
#        [-20.89613873, -20.89613873, -20.89613873, ..., -20.89613873,
#         -20.89613873, -20.89613873],
#        [-20.35378219, -13.69557071, -13.69557071, ..., -20.35378219,
#         -20.35378219, -20.35378219]])

# %%
results = read_in_print_out(test, transition, observation, vocabulary, path ="Data/", name = 'test2')

# %%
results
# Out:
#       word_Num                word tag
# 0            1       Pharmacologic   O
# 1            2             aspects   O
# 2            3                  of   O
# 3            4            neonatal   O
# 4            5  hyperbilirubinemia   O
# 5            6                   .   O
# 6
# 7            1                SGPT   O
# 8            2                   ,   O
# 9            3                SGOT   O
# 10           4                   ,   O
# 11           5                 and   O
# 12           6            alkaline   B
# 13           7         phosphatase   I
# 14           8      concentrations   O
# 15           9                were   O
# 16          10         essentially   O
# 17          11              normal   O
# 18          12                  in   O
# 19          13                 all   O
# 20          14            subjects   O
# 21          15                   .   O
# 22
# 23           1            Patients   O
# 24           2                with   O
# 25           3           Parkinson   O
# 26           4                   '   O
# 27           5                   s   O
# 28           6             disease   O
# 29           7              showed   O
# ...        ...                 ...  ..
# 80343        2             epitope   O
# 80344        3                   -   O
# 80345        4           protected   O
# 80346        5              lysine   O
# 80347        6                   (   O
# 80348        7                   K   O
# 80349        8                   )   O
# 80350        9                 was   O
# 80351       10             present   O
# 80352       11                  in   O
# 80353       12                   a   O
# 80354       13                  30   O
# 80355       14                   -   O
# 80356       15                  aa   O
# 80357       16                 TPO   O
# 80358       17            fragment   O
# 80359       18                that   O
# 80360       19                   ,   O
# 80361       20                  by   O
# 80362       21                   N   O
# 80363       22                   -   O
# 80364       23            terminal   O
# 80365       24          sequencing   O
# 80366       25                   ,   O
# 80367       26                 was   O
# 80368       27               found   O
# 80369       28                  to   O
# 80370       29                  be   O
# 80371       30                K713   O
# 80372       31                   .   O
#
# [80373 rows x 3 columns]
